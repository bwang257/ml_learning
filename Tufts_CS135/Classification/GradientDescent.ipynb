# %% [markdown]
# # Gradient Descent for Linear Regression
#
# # Objectives
#
# * Learn how to fit weight parameters of Linear Regression to a simple dataset via gradient descent
# * Understand impact of step size
# * Understand impact of initialization
#
#
# # Outline
# * [Part 1: Loss and Gradient for 1-dim. Linear Regression](#part1)
# * [Part 2: Gradient Descent Algorithm in a few lines of Python](#part2)
# * [Part 3: Debugging with Trace Plots](#part3)
# * [Part 4: Selecting the step size](#part4)
# * [Part 5: Selecting the initialization](#part5)
# * [Part 6: Using SciPy's built-in routines](#part6)
#
# # Takeaways
#
#
# * Gradient descent is a simple algorithm that can be implemented in a few lines of Python
# * * Practical issues include selecting step size and initialization
# * Step size matters a lot
# * * Need to select carefully for each problem
#
# * Initialization of the parameters can matter too!
#
# * scipy offers some useful tools for gradient-based optimization
# * * "L-BFGS-B" method is highly recommended if you have your loss and gradient functions available

# %%
import numpy as np

# %%
# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set_theme('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Create simple dataset:   y = 1.234 * x + noise
#
# We will *intentionally* create a toy dataset where we know that a good solution has slope near 1.234.
#
# Naturally, the best slope for the finite dataset of N=100 examples we create won't be exactly 1.234 (because of the noise added plus the fact that our dataset size is limited).

# %%
def create_dataset(N=100, slope=1.234, noise_stddev=0.1, random_state=0):
    random_state = np.random.RandomState(int(random_state))

    # input features
    x_N = np.linspace(-2, 2, N)
    
    # output features
    y_N = slope * x_N + random_state.randn(N) * noise_stddev
    
    return x_N, y_N

# %%
x_N, y_N = create_dataset(N=50, noise_stddev=0.3)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))
plt.plot(x_N, y_N, 'k.');
plt.xlabel('x');
plt.ylabel('y');

# %% [markdown]
# <a id="part1"></a>
# # Part 1: Gradient Descent for 1-dim. Linear Regression

# %% [markdown]
# ## Define model
#
# Consider the *simplest* linear regression model. A single weight parameter $w \in \mathbb{R}$ representing the slope of the prediction line. No bias/intercept.
#
# To make predictions, we just compute the weight multiplied by the input feature
# $$
# \hat{y}(x) = w \cdot x
# $$

# %% [markdown]
# ## Define loss function

# %% [markdown]
# We want to minimize the total *squared error* across all N observed data examples (input features $x_n$, output responses $y_n$)

# %% [markdown]
# \begin{align}
#     \min_{w \in \mathbb{R}} ~~ &J(w)
#     \\
#     \text{calc\_loss}(w) = J(w) &= \sum_{n=1}^N (y_n - w x_n)^2
# \end{align}

# %% [markdown]
# ### Exercise 1A: Complete the code below
#
# You should make it match the math expression above.

# %%
def calc_loss(w):
    ''' Compute loss for slope-only least-squares linear regression
    
    Args
    ----
    w : float
        Value of slope parameter

    Returns
    -------
    loss : float
        Sum of squared error loss at provided w value
    '''
    yhat_N = x_N * w
    sum_squared_error = np.sum(np.square(y_N - yhat_N))

    return sum_squared_error

# %% [markdown]
# # Define the gradient function
#
# \begin{align}
# \text{calc\_grad}(w) = J'(w) &= \frac{\partial}{\partial w} [ \sum_{n=1}^N (y_n - w x_n)^2]
# \\
# &= \sum_{n=1}^N 2 (y_n - w x_n) (-x_n)
# \\
# &= 2 \sum_{n=1}^N (w x_n - y_n) (x_n)
# \\
# &= 2  w \left( \sum_{n=1}^N x_n^2 \right) - 2 \sum_{n=1}^N y_n x_n
# \end{align}

# %% [markdown]
# Below, we've implemented the gradient calculation in code for you.
#
# You don't need to edit this, but look over it and verify you understand it.

# %%
def calc_grad(w):
    ''' Compute gradient for slope-only least-squares linear regression
    
    Args
    ----
    w : float
        Value of slope parameter

    Returns
    -------
    g : float
        Value of derivative of loss function at provided w value
    '''
    g = 2.0 * w * np.sum(np.square(x_N)) - 2.0 * np.sum(x_N * y_N)
    return g

# %% [markdown]
# ## Plot loss evaluated at each w from -3 to 8
#
# We should see a "bowl" shape with one *global* minima, because our optimization problem is "convex"

# %%
w_grid = np.linspace(-3, 8, 300) # create array of 300 values between -3 and 8

# %%
loss_grid = np.asarray([calc_loss(w) for w in w_grid])
plt.plot(w_grid, loss_grid, 'b.-');
plt.xlabel('w');
plt.ylabel('loss(w)');

# %% [markdown]
# ### Discussion 1b: Visually, at what value of $w$ does the loss function have a minima? Is it near where you would expect (hint: look above for the "true" slope value used to generate the data)

# %% [markdown]
# Min of w occurs around 1.2, which is close to the "true" slope value used to generate the data.

# %% [markdown]
# ### Exercise 1c: Write NumPy code to identify which entry in the w_grid array corresponds to the lowest entry in the loss_grid array
#
# Hint: use np.argmin

# %%
min_loss_index = np.argmin(loss_grid)
print("Weight:", w_grid[min_loss_index])
print("Loss:", loss_grid[min_loss_index])
# Out:
# Weight: 1.120401337792643
# Loss: 5.015902819280258

# %% [markdown]
# ## Sanity check: plot gradient evaluated at each w from -3 to 8

# %%
grad_grid = np.asarray([calc_grad(w) for w in w_grid])
plt.plot(w_grid, grad_grid, 'b.-');
plt.xlabel('w');
plt.ylabel('grad(w)');

# %% [markdown]
# ### Exercise 1d: Numerically, at which value of w does grad_grid cross zero?

# %% [markdown]
# We might try to estimate numerically where the gradient crosses zero.
#
# We could do this in a few steps:
#
# 1) Compute the distance from each gradient in `grad_grid` to 0.0 (we could use just absolute distance)
#
# 2) Find the index of `grad_grid` with smallest distance (using `np.argmin`)
#
# 3) Plug that index into `w_grid` to get the $w$ value corresponding to that zero-crossing

# %%
dist_from_zero_G = np.abs(grad_grid - 0.0)

zero_cross_index = np.argmin(dist_from_zero_G)

print("Zero crossing occurs at w = %.4f" % w_grid[zero_cross_index])
# Out:
# Zero crossing occurs at w = 1.1204

# %% [markdown]
# <a id="part2"></a>
#
# ## Part 2: Gradient Descent (GD) as an algorithm in Python
#
#
# ### Define minimize_via_grad_descent algorithm
#
# Can you understand what each step of this algorithm does?

# %%
def minimize_via_grad_descent(calc_loss, calc_grad, init_w=0.0, step_size=0.001, max_iters=100):
    ''' Perform minimization of provided loss function via gradient descent
    
    Args
    ----
    calc_loss : function
    calc_grad : function
    init_w : float
    step_size : float
    max_iters : positive int
    
    Return
    ----
    wopt: float
        array of optimized weights that approximately gives the least error
    info_dict : dict
        Contains information about the optimization procedure useful for debugging
        Entries include:
        * trace_loss_list : list of loss values
        * trace_grad_list : list of gradient values
    '''
    w = 1.0 * init_w 
    grad = calc_grad(w)

    # Create some lists to track progress over time (for debugging)
    trace_loss_list = []
    trace_w_list = []
    trace_grad_list = []

    for iter_id in range(max_iters):
        if iter_id > 0:
            w = w - step_size * grad
        
        loss = calc_loss(w)
        grad = calc_grad(w)    

        print("iter %4d/%d | w  % 8.4f | loss % 8.4f | grad % 8.4f" % (
            iter_id, max_iters, w, loss, grad))
    
        trace_loss_list.append(loss)
        trace_w_list.append(w)
        trace_grad_list.append(grad)
    
    wopt = w
    info_dict = dict(
        trace_loss_list=trace_loss_list,
        trace_w_list=trace_w_list, 
        trace_grad_list=trace_grad_list)
    
    return wopt, info_dict

# %% [markdown]
# ### Try it! Run GD with step_size = 0.001
#
# Running the cell below will have the following effects:
#
# 1) one line will be printed for every iteration, indicating the current w value and its associated loss
#
# 2) the "optimal" value of w will be stored in the variable named `wopt` returned by this function
#
# 3) a dictionary of information useful for debugging will be stored in the `info_dict` returned by this function

# %%
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.001);
# Out:
# iter    0/100 | w    0.0000 | loss  93.3197 | grad -156.5566
# iter    1/100 | w    0.1566 | loss  70.5104 | grad -134.8304
# iter    2/100 | w    0.2914 | loss  53.5926 | grad -116.1192
# iter    3/100 | w    0.4075 | loss  41.0446 | grad -100.0047
# iter    4/100 | w    0.5075 | loss  31.7376 | grad -86.1265
# iter    5/100 | w    0.5936 | loss  24.8345 | grad -74.1743
# iter    6/100 | w    0.6678 | loss  19.7144 | grad -63.8807
# iter    7/100 | w    0.7317 | loss  15.9168 | grad -55.0156
# iter    8/100 | w    0.7867 | loss  13.1001 | grad -47.3808
# iter    9/100 | w    0.8341 | loss  11.0110 | grad -40.8055
# iter   10/100 | w    0.8749 | loss   9.4614 | grad -35.1427
# iter   11/100 | w    0.9100 | loss   8.3121 | grad -30.2657
# iter   12/100 | w    0.9403 | loss   7.4597 | grad -26.0656
# iter   13/100 | w    0.9664 | loss   6.8274 | grad -22.4483
# iter   14/100 | w    0.9888 | loss   6.3584 | grad -19.3331
# iter   15/100 | w    1.0081 | loss   6.0106 | grad -16.6501
# iter   16/100 | w    1.0248 | loss   5.7526 | grad -14.3395
# iter   17/100 | w    1.0391 | loss   5.5612 | grad -12.3495
# iter   18/100 | w    1.0515 | loss   5.4193 | grad -10.6357
# iter   19/100 | w    1.0621 | loss   5.3140 | grad  -9.1597
# iter   20/100 | w    1.0713 | loss   5.2360 | grad  -7.8886
# iter   21/100 | w    1.0792 | loss   5.1781 | grad  -6.7938
# iter   22/100 | w    1.0860 | loss   5.1351 | grad  -5.8510
# iter   23/100 | w    1.0918 | loss   5.1032 | grad  -5.0390
# iter   24/100 | w    1.0969 | loss   5.0796 | grad  -4.3397
# iter   25/100 | w    1.1012 | loss   5.0621 | grad  -3.7375
# iter   26/100 | w    1.1049 | loss   5.0491 | grad  -3.2188
# iter   27/100 | w    1.1082 | loss   5.0394 | grad  -2.7721
# iter   28/100 | w    1.1109 | loss   5.0323 | grad  -2.3874
# iter   29/100 | w    1.1133 | loss   5.0270 | grad  -2.0561
# iter   30/100 | w    1.1154 | loss   5.0231 | grad  -1.7708
# iter   31/100 | w    1.1171 | loss   5.0201 | grad  -1.5250
# iter   32/100 | w    1.1187 | loss   5.0180 | grad  -1.3134
# iter   33/100 | w    1.1200 | loss   5.0164 | grad  -1.1311
# iter   34/100 | w    1.1211 | loss   5.0152 | grad  -0.9742
# iter   35/100 | w    1.1221 | loss   5.0143 | grad  -0.8390
# iter   36/100 | w    1.1229 | loss   5.0136 | grad  -0.7225
# iter   37/100 | w    1.1236 | loss   5.0132 | grad  -0.6223
# iter   38/100 | w    1.1243 | loss   5.0128 | grad  -0.5359
# iter   39/100 | w    1.1248 | loss   5.0125 | grad  -0.4615
# iter   40/100 | w    1.1253 | loss   5.0123 | grad  -0.3975
# iter   41/100 | w    1.1257 | loss   5.0122 | grad  -0.3423
# iter   42/100 | w    1.1260 | loss   5.0121 | grad  -0.2948
# iter   43/100 | w    1.1263 | loss   5.0120 | grad  -0.2539
# iter   44/100 | w    1.1266 | loss   5.0119 | grad  -0.2187
# iter   45/100 | w    1.1268 | loss   5.0119 | grad  -0.1883
# iter   46/100 | w    1.1270 | loss   5.0119 | grad  -0.1622
# iter   47/100 | w    1.1271 | loss   5.0118 | grad  -0.1397
# iter   48/100 | w    1.1273 | loss   5.0118 | grad  -0.1203
# iter   49/100 | w    1.1274 | loss   5.0118 | grad  -0.1036
# iter   50/100 | w    1.1275 | loss   5.0118 | grad  -0.0892
# iter   51/100 | w    1.1276 | loss   5.0118 | grad  -0.0768
# iter   52/100 | w    1.1277 | loss   5.0118 | grad  -0.0662
# iter   53/100 | w    1.1277 | loss   5.0118 | grad  -0.0570
# iter   54/100 | w    1.1278 | loss   5.0118 | grad  -0.0491
# iter   55/100 | w    1.1278 | loss   5.0118 | grad  -0.0423
# iter   56/100 | w    1.1279 | loss   5.0118 | grad  -0.0364
# iter   57/100 | w    1.1279 | loss   5.0118 | grad  -0.0314
# iter   58/100 | w    1.1279 | loss   5.0118 | grad  -0.0270
# iter   59/100 | w    1.1280 | loss   5.0118 | grad  -0.0233
# iter   60/100 | w    1.1280 | loss   5.0118 | grad  -0.0200
# iter   61/100 | w    1.1280 | loss   5.0118 | grad  -0.0172
# iter   62/100 | w    1.1280 | loss   5.0118 | grad  -0.0149
# iter   63/100 | w    1.1280 | loss   5.0118 | grad  -0.0128
# iter   64/100 | w    1.1280 | loss   5.0118 | grad  -0.0110
# iter   65/100 | w    1.1281 | loss   5.0118 | grad  -0.0095
# iter   66/100 | w    1.1281 | loss   5.0118 | grad  -0.0082
# iter   67/100 | w    1.1281 | loss   5.0118 | grad  -0.0070
# iter   68/100 | w    1.1281 | loss   5.0118 | grad  -0.0061
# iter   69/100 | w    1.1281 | loss   5.0118 | grad  -0.0052
# iter   70/100 | w    1.1281 | loss   5.0118 | grad  -0.0045
# iter   71/100 | w    1.1281 | loss   5.0118 | grad  -0.0039
# iter   72/100 | w    1.1281 | loss   5.0118 | grad  -0.0033
# iter   73/100 | w    1.1281 | loss   5.0118 | grad  -0.0029
# iter   74/100 | w    1.1281 | loss   5.0118 | grad  -0.0025
# iter   75/100 | w    1.1281 | loss   5.0118 | grad  -0.0021
# iter   76/100 | w    1.1281 | loss   5.0118 | grad  -0.0018
# iter   77/100 | w    1.1281 | loss   5.0118 | grad  -0.0016
# iter   78/100 | w    1.1281 | loss   5.0118 | grad  -0.0014
# iter   79/100 | w    1.1281 | loss   5.0118 | grad  -0.0012
# iter   80/100 | w    1.1281 | loss   5.0118 | grad  -0.0010
# iter   81/100 | w    1.1281 | loss   5.0118 | grad  -0.0009
# iter   82/100 | w    1.1281 | loss   5.0118 | grad  -0.0007
# iter   83/100 | w    1.1281 | loss   5.0118 | grad  -0.0006
# iter   84/100 | w    1.1281 | loss   5.0118 | grad  -0.0006
# iter   85/100 | w    1.1281 | loss   5.0118 | grad  -0.0005
# iter   86/100 | w    1.1281 | loss   5.0118 | grad  -0.0004
# iter   87/100 | w    1.1281 | loss   5.0118 | grad  -0.0004
# iter   88/100 | w    1.1281 | loss   5.0118 | grad  -0.0003
# iter   89/100 | w    1.1281 | loss   5.0118 | grad  -0.0003
# iter   90/100 | w    1.1281 | loss   5.0118 | grad  -0.0002
# iter   91/100 | w    1.1281 | loss   5.0118 | grad  -0.0002
# iter   92/100 | w    1.1281 | loss   5.0118 | grad  -0.0002
# iter   93/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   94/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   95/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   96/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   97/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   98/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   99/100 | w    1.1281 | loss   5.0118 | grad  -0.0001

# %% [markdown]
# ### Exercise 2d: What exactly is the gradient of the returned "optimal" value of w?
#
# Use your `calc_grad` function to check the result. What is the gradient of the returned `wopt`?
#
# Does this look totally converged? Can you find a $w$ value that would be even better?

# %%
optimal_grad = calc_grad(wopt)
print(f"The gradient of the optimal weight {wopt} is {optimal_grad}")
# Out:
# The gradient of the optimal weight 1.128127887545667 is -5.9046213692681704e-05

# %%
step_size = 0.001
new_optimal = wopt - (step_size * optimal_grad)
new_loss = calc_loss(new_optimal)
old_loss = calc_loss(wopt)
assert(new_loss < old_loss)

# %% [markdown]
# <a id="part3"></a>
#
# ## Part 3: Diagnostic plots for gradient descent

# %% [markdown]
# Let's look at some trace functions.
#
# Whenever you run gradient descent, an *excellent* debugging strategy is the ability to plot the loss, the gradient magnitude, and the parameter of interest at every step of the algorithm.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=False, figsize=(18,3.6))

axes[0].plot(info_dict['trace_loss_list']);
axes[0].set_title('loss');
axes[1].plot(info_dict['trace_grad_list']);
axes[1].set_title('grad');
axes[2].plot(info_dict['trace_w_list']);
axes[2].set_title('w');

plt.xlim([0, 100]);

# %% [markdown]
# <a id="part4"></a>
#
#
# # Part 4: Larger step sizes
#
# ## Try with larger step_size = 0.014

# %%
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.014);
# Out:
# iter    0/100 | w    0.0000 | loss  93.3197 | grad -156.5566
# iter    1/100 | w    2.1918 | loss  83.5157 | grad  147.6105
# iter    2/100 | w    0.1252 | loss  74.8002 | grad -139.1756
# iter    3/100 | w    2.0737 | loss  67.0522 | grad  131.2227
# iter    4/100 | w    0.2366 | loss  60.1645 | grad -123.7243
# iter    5/100 | w    1.9687 | loss  54.0414 | grad  116.6543
# iter    6/100 | w    0.3356 | loss  48.5981 | grad -109.9884
# iter    7/100 | w    1.8754 | loss  43.7591 | grad  103.7033
# iter    8/100 | w    0.4236 | loss  39.4574 | grad -97.7774
# iter    9/100 | w    1.7924 | loss  35.6332 | grad  92.1901
# iter   10/100 | w    0.5018 | loss  32.2336 | grad -86.9221
# iter   11/100 | w    1.7187 | loss  29.2114 | grad  81.9551
# iter   12/100 | w    0.5713 | loss  26.5248 | grad -77.2720
# iter   13/100 | w    1.6531 | loss  24.1364 | grad  72.8564
# iter   14/100 | w    0.6331 | loss  22.0132 | grad -68.6932
# iter   15/100 | w    1.5948 | loss  20.1257 | grad  64.7679
# iter   16/100 | w    0.6881 | loss  18.4477 | grad -61.0669
# iter   17/100 | w    1.5430 | loss  16.9560 | grad  57.5773
# iter   18/100 | w    0.7369 | loss  15.6300 | grad -54.2872
# iter   19/100 | w    1.4970 | loss  14.4511 | grad  51.1851
# iter   20/100 | w    0.7804 | loss  13.4032 | grad -48.2602
# iter   21/100 | w    1.4560 | loss  12.4716 | grad  45.5025
# iter   22/100 | w    0.8190 | loss  11.6434 | grad -42.9023
# iter   23/100 | w    1.4196 | loss  10.9071 | grad  40.4508
# iter   24/100 | w    0.8533 | loss  10.2526 | grad -38.1393
# iter   25/100 | w    1.3873 | loss   9.6708 | grad  35.9599
# iter   26/100 | w    0.8838 | loss   9.1535 | grad -33.9051
# iter   27/100 | w    1.3585 | loss   8.6937 | grad  31.9676
# iter   28/100 | w    0.9109 | loss   8.2849 | grad -30.1409
# iter   29/100 | w    1.3329 | loss   7.9216 | grad  28.4186
# iter   30/100 | w    0.9350 | loss   7.5985 | grad -26.7947
# iter   31/100 | w    1.3102 | loss   7.3113 | grad  25.2635
# iter   32/100 | w    0.9565 | loss   7.0560 | grad -23.8199
# iter   33/100 | w    1.2900 | loss   6.8291 | grad  22.4588
# iter   34/100 | w    0.9755 | loss   6.6273 | grad -21.1754
# iter   35/100 | w    1.2720 | loss   6.4480 | grad  19.9654
# iter   36/100 | w    0.9925 | loss   6.2885 | grad -18.8245
# iter   37/100 | w    1.2560 | loss   6.1468 | grad  17.7488
# iter   38/100 | w    1.0075 | loss   6.0208 | grad -16.7346
# iter   39/100 | w    1.2418 | loss   5.9087 | grad  15.7783
# iter   40/100 | w    1.0209 | loss   5.8092 | grad -14.8767
# iter   41/100 | w    1.2292 | loss   5.7206 | grad  14.0266
# iter   42/100 | w    1.0328 | loss   5.6419 | grad -13.2251
# iter   43/100 | w    1.2180 | loss   5.5720 | grad  12.4694
# iter   44/100 | w    1.0434 | loss   5.5098 | grad -11.7568
# iter   45/100 | w    1.2080 | loss   5.4545 | grad  11.0850
# iter   46/100 | w    1.0528 | loss   5.4053 | grad -10.4516
# iter   47/100 | w    1.1991 | loss   5.3616 | grad   9.8544
# iter   48/100 | w    1.0612 | loss   5.3228 | grad  -9.2913
# iter   49/100 | w    1.1913 | loss   5.2883 | grad   8.7603
# iter   50/100 | w    1.0686 | loss   5.2576 | grad  -8.2597
# iter   51/100 | w    1.1842 | loss   5.2303 | grad   7.7878
# iter   52/100 | w    1.0752 | loss   5.2060 | grad  -7.3427
# iter   53/100 | w    1.1780 | loss   5.1844 | grad   6.9232
# iter   54/100 | w    1.0811 | loss   5.1653 | grad  -6.5275
# iter   55/100 | w    1.1725 | loss   5.1482 | grad   6.1545
# iter   56/100 | w    1.0863 | loss   5.1331 | grad  -5.8029
# iter   57/100 | w    1.1676 | loss   5.1196 | grad   5.4713
# iter   58/100 | w    1.0910 | loss   5.1076 | grad  -5.1586
# iter   59/100 | w    1.1632 | loss   5.0970 | grad   4.8638
# iter   60/100 | w    1.0951 | loss   5.0875 | grad  -4.5859
# iter   61/100 | w    1.1593 | loss   5.0791 | grad   4.3239
# iter   62/100 | w    1.0988 | loss   5.0716 | grad  -4.0768
# iter   63/100 | w    1.1558 | loss   5.0650 | grad   3.8438
# iter   64/100 | w    1.1020 | loss   5.0591 | grad  -3.6242
# iter   65/100 | w    1.1528 | loss   5.0538 | grad   3.4171
# iter   66/100 | w    1.1049 | loss   5.0492 | grad  -3.2218
# iter   67/100 | w    1.1500 | loss   5.0450 | grad   3.0377
# iter   68/100 | w    1.1075 | loss   5.0413 | grad  -2.8641
# iter   69/100 | w    1.1476 | loss   5.0380 | grad   2.7005
# iter   70/100 | w    1.1098 | loss   5.0351 | grad  -2.5462
# iter   71/100 | w    1.1454 | loss   5.0325 | grad   2.4007
# iter   72/100 | w    1.1118 | loss   5.0302 | grad  -2.2635
# iter   73/100 | w    1.1435 | loss   5.0282 | grad   2.1341
# iter   74/100 | w    1.1136 | loss   5.0263 | grad  -2.0122
# iter   75/100 | w    1.1418 | loss   5.0247 | grad   1.8972
# iter   76/100 | w    1.1152 | loss   5.0233 | grad  -1.7888
# iter   77/100 | w    1.1403 | loss   5.0220 | grad   1.6866
# iter   78/100 | w    1.1167 | loss   5.0209 | grad  -1.5902
# iter   79/100 | w    1.1389 | loss   5.0199 | grad   1.4993
# iter   80/100 | w    1.1179 | loss   5.0190 | grad  -1.4137
# iter   81/100 | w    1.1377 | loss   5.0182 | grad   1.3329
# iter   82/100 | w    1.1191 | loss   5.0175 | grad  -1.2567
# iter   83/100 | w    1.1367 | loss   5.0168 | grad   1.1849
# iter   84/100 | w    1.1201 | loss   5.0163 | grad  -1.1172
# iter   85/100 | w    1.1357 | loss   5.0158 | grad   1.0533
# iter   86/100 | w    1.1210 | loss   5.0153 | grad  -0.9932
# iter   87/100 | w    1.1349 | loss   5.0149 | grad   0.9364
# iter   88/100 | w    1.1218 | loss   5.0146 | grad  -0.8829
# iter   89/100 | w    1.1341 | loss   5.0143 | grad   0.8324
# iter   90/100 | w    1.1225 | loss   5.0140 | grad  -0.7849
# iter   91/100 | w    1.1335 | loss   5.0137 | grad   0.7400
# iter   92/100 | w    1.1231 | loss   5.0135 | grad  -0.6977
# iter   93/100 | w    1.1329 | loss   5.0133 | grad   0.6579
# iter   94/100 | w    1.1237 | loss   5.0131 | grad  -0.6203
# iter   95/100 | w    1.1323 | loss   5.0130 | grad   0.5848
# iter   96/100 | w    1.1242 | loss   5.0129 | grad  -0.5514
# iter   97/100 | w    1.1319 | loss   5.0127 | grad   0.5199
# iter   98/100 | w    1.1246 | loss   5.0126 | grad  -0.4902
# iter   99/100 | w    1.1315 | loss   5.0125 | grad   0.4622

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=False, figsize=(12,3))

axes[0].plot(info_dict['trace_loss_list'], '.-');
axes[0].set_title('loss');
axes[1].plot(info_dict['trace_grad_list'], '.-');
axes[1].set_title('grad');
axes[2].plot(info_dict['trace_w_list'], '.-');
axes[2].set_title('w');

# %% [markdown]
# ## Try with even larger step size 0.1

# %%
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.1, max_iters=25);
# Out:
# iter    0/25 | w    0.0000 | loss  93.3197 | grad -156.5566
# iter    1/25 | w   15.6557 | loss  14649.2368 | grad  2016.0654
# iter    2/25 | w  -185.9509 | loss  2428476.1808 | grad -25961.9847
# iter    3/25 | w   2410.2476 | loss  402716585.2503 | grad  334326.7829
# iter    4/25 | w  -31022.4307 | loss  66783022205.9171 | grad -4305310.2046
# iter    5/25 | w   399508.5898 | loss  11074716744084.4141 | grad  55441851.8184
# iter    6/25 | w  -5144676.5921 | loss  1836534899433323.2500 | grad -713955275.4570
# iter    7/25 | w   66250850.9536 | loss  304555007119229056.0000 | grad  9193995485.9874
# iter    8/25 | w  -853148697.6451 | loss  50504758929445773312.0000 | grad -118396145952.2056
# iter    9/25 | w   10986465897.5754 | loss  8375270853855496110080.0000 | grad  1524652410119.2183
# iter   10/25 | w  -141478775114.3464 | loss  1388882223424388487708672.0000 | grad -19633789199698.5000
# iter   11/25 | w   1821900144855.5037 | loss  230320172828353878072229888.0000 | grad  252835122143056.1250
# iter   12/25 | w  -23461612069450.1094 | loss  38194298347984235566746042368.0000 | grad -3255897185148334.0000
# iter   13/25 | w   302128106445383.3125 | loss  6333810922337253002324901625856.0000 | grad  41927982118950984.0000
# iter   14/25 | w  -3890670105449715.0000 | loss  1050344227675435594616612241539072.0000 | grad -539929728919552256.0000
# iter   15/25 | w   50102302786505520.0000 | loss  174179970027271567056475537700552704.0000 | grad  6952972631596682240.0000
# iter   16/25 | w  -645194960373162752.0000 | loss  28884494396513295581582150224859627520.0000 | grad -89537259806887870464.0000
# iter   17/25 | w   8308531020315624448.0000 | loss  4789953841486933888993409867170069872640.0000 | grad  1153020631390739496960.0000
# iter   18/25 | w  -106993532118758326272.0000 | loss  794324369629436915247881923050492605235200.0000 | grad -14848082008317477519360.0000
# iter   19/25 | w   1377814668712989425664.0000 | loss  131723858948782180577106647540510996691943424.0000 | grad  191206933617312775798784.0000
# iter   20/25 | w  -17742878693018289831936.0000 | loss  21843941442276573541864616173554104972001411072.0000 | grad -2462277043112741494063104.0000
# iter   21/25 | w   228484825618255890612224.0000 | loss  3622409649561965380207861922238472078510690140160.0000 | grad  31708098249064074287513600.0000
# iter   22/25 | w  -2942324999288151773020160.0000 | loss  600708974793519752090966724917105170766253120290816.0000 | grad -408322652962437261462339584.0000
# iter   23/25 | w   37889940296955572118355968.0000 | loss  99616362395986024613809581522281286396676988509093888.0000 | grad  5258195796312200821216378880.0000
# iter   24/25 | w  -487929639334264484233478144.0000 | loss  16519512897937594771338113222367982867942815032542232576.0000 | grad -67712684642306077575404847104.0000

# %% [markdown]
# ### Exercise 3c: What is the largest step size you can get to converge reasonably?

# %%
# TODO try some other step sizes here
wopt, info_dict = minimize_via_grad_descent(calc_loss, calc_grad, step_size=0.004)
# Out:
# iter    0/100 | w    0.0000 | loss  93.3197 | grad -156.5566
# iter    1/100 | w    0.6262 | loss  22.4909 | grad -69.6517
# iter    2/100 | w    0.9048 | loss   8.4715 | grad -30.9879
# iter    3/100 | w    1.0288 | loss   5.6966 | grad -13.7865
# iter    4/100 | w    1.0839 | loss   5.1473 | grad  -6.1336
# iter    5/100 | w    1.1085 | loss   5.0386 | grad  -2.7288
# iter    6/100 | w    1.1194 | loss   5.0171 | grad  -1.2140
# iter    7/100 | w    1.1242 | loss   5.0128 | grad  -0.5401
# iter    8/100 | w    1.1264 | loss   5.0120 | grad  -0.2403
# iter    9/100 | w    1.1274 | loss   5.0118 | grad  -0.1069
# iter   10/100 | w    1.1278 | loss   5.0118 | grad  -0.0476
# iter   11/100 | w    1.1280 | loss   5.0118 | grad  -0.0212
# iter   12/100 | w    1.1281 | loss   5.0118 | grad  -0.0094
# iter   13/100 | w    1.1281 | loss   5.0118 | grad  -0.0042
# iter   14/100 | w    1.1281 | loss   5.0118 | grad  -0.0019
# iter   15/100 | w    1.1281 | loss   5.0118 | grad  -0.0008
# iter   16/100 | w    1.1281 | loss   5.0118 | grad  -0.0004
# iter   17/100 | w    1.1281 | loss   5.0118 | grad  -0.0002
# iter   18/100 | w    1.1281 | loss   5.0118 | grad  -0.0001
# iter   19/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   20/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   21/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   22/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   23/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   24/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   25/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   26/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   27/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   28/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   29/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   30/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   31/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   32/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   33/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   34/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   35/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   36/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   37/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   38/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   39/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   40/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   41/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   42/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   43/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   44/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   45/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   46/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   47/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   48/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   49/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   50/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   51/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   52/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   53/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   54/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   55/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   56/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   57/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   58/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   59/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   60/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   61/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   62/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   63/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   64/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   65/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   66/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   67/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   68/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   69/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   70/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   71/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   72/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   73/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   74/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   75/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   76/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   77/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   78/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   79/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   80/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   81/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   82/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   83/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   84/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   85/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   86/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   87/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   88/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   89/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   90/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   91/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   92/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   93/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   94/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   95/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   96/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   97/100 | w    1.1281 | loss   5.0118 | grad  -0.0000
# iter   98/100 | w    1.1281 | loss   5.0118 | grad   0.0000
# iter   99/100 | w    1.1281 | loss   5.0118 | grad  -0.0000

# %% [markdown]
# <a id="part5"></a>
#
#
# # Part 5: Sensitivity to initial conditions

# %% [markdown]
# ### Exercise 5a: Try to call the defined procedure with a different initial condition for $w$. What happens?
#
# You could try $w = 5.0$ or something else.

# %%
# try some other initial condition for init_w
wopt2, info_dict2 = minimize_via_grad_descent(calc_loss, calc_grad, init_w=10, step_size=0.001, max_iters=40)
# Out:
# iter    0/40 | w   10.0000 | loss  5466.5294 | grad  1231.1985
# iter    1/40 | w    8.7688 | loss  4055.8610 | grad  1060.3383
# iter    2/40 | w    7.7085 | loss  3009.5575 | grad  913.1893
# iter    3/40 | w    6.7953 | loss  2233.5063 | grad  786.4610
# iter    4/40 | w    6.0088 | loss  1657.9031 | grad  677.3195
# iter    5/40 | w    5.3315 | loss  1230.9739 | grad  583.3241
# iter    6/40 | w    4.7482 | loss  914.3172 | grad  502.3730
# iter    7/40 | w    4.2458 | loss  679.4505 | grad  432.6560
# iter    8/40 | w    3.8131 | loss  505.2481 | grad  372.6139
# iter    9/40 | w    3.4405 | loss  376.0409 | grad  320.9042
# iter   10/40 | w    3.1196 | loss  280.2069 | grad  276.3706
# iter   11/40 | w    2.8433 | loss  209.1261 | grad  238.0171
# iter   12/40 | w    2.6052 | loss  156.4049 | grad  204.9862
# iter   13/40 | w    2.4002 | loss  117.3012 | grad  176.5391
# iter   14/40 | w    2.2237 | loss  88.2977 | grad  152.0398
# iter   15/40 | w    2.0717 | loss  66.7856 | grad  130.9404
# iter   16/40 | w    1.9407 | loss  50.8299 | grad  112.7691
# iter   17/40 | w    1.8280 | loss  38.9954 | grad  97.1195
# iter   18/40 | w    1.7308 | loss  30.2177 | grad  83.6417
# iter   19/40 | w    1.6472 | loss  23.7072 | grad  72.0343
# iter   20/40 | w    1.5752 | loss  18.8783 | grad  62.0377
# iter   21/40 | w    1.5131 | loss  15.2967 | grad  53.4284
# iter   22/40 | w    1.4597 | loss  12.6402 | grad  46.0138
# iter   23/40 | w    1.4137 | loss  10.6698 | grad  39.6282
# iter   24/40 | w    1.3741 | loss   9.2084 | grad  34.1288
# iter   25/40 | w    1.3399 | loss   8.1244 | grad  29.3926
# iter   26/40 | w    1.3105 | loss   7.3204 | grad  25.3136
# iter   27/40 | w    1.2852 | loss   6.7241 | grad  21.8007
# iter   28/40 | w    1.2634 | loss   6.2818 | grad  18.7753
# iter   29/40 | w    1.2446 | loss   5.9538 | grad  16.1697
# iter   30/40 | w    1.2285 | loss   5.7105 | grad  13.9258
# iter   31/40 | w    1.2146 | loss   5.5300 | grad  11.9932
# iter   32/40 | w    1.2026 | loss   5.3961 | grad  10.3288
# iter   33/40 | w    1.1922 | loss   5.2969 | grad   8.8955
# iter   34/40 | w    1.1833 | loss   5.2232 | grad   7.6610
# iter   35/40 | w    1.1757 | loss   5.1686 | grad   6.5978
# iter   36/40 | w    1.1691 | loss   5.1281 | grad   5.6822
# iter   37/40 | w    1.1634 | loss   5.0980 | grad   4.8937
# iter   38/40 | w    1.1585 | loss   5.0758 | grad   4.2145
# iter   39/40 | w    1.1543 | loss   5.0592 | grad   3.6297

# %% [markdown]
# ### Exercise 5b: Try again with another initial value.

# %%
# try some other initial condition for init_w
wopt3, info_dict3 = minimize_via_grad_descent(calc_loss, calc_grad, init_w=-30, step_size=0.001, max_iters=40)
# Out:
# iter    0/40 | w  -30.0000 | loss  67238.9968 | grad -4319.8219
# iter    1/40 | w  -25.6802 | loss  49872.9709 | grad -3720.3364
# iter    2/40 | w  -21.9598 | loss  36992.4571 | grad -3204.0448
# iter    3/40 | w  -18.7558 | loss  27438.8819 | grad -2759.4019
# iter    4/40 | w  -15.9964 | loss  20352.9223 | grad -2376.4645
# iter    5/40 | w  -13.6199 | loss  15097.2121 | grad -2046.6694
# iter    6/40 | w  -11.5733 | loss  11199.0118 | grad -1762.6418
# iter    7/40 | w   -9.8106 | loss  8307.6869 | grad -1518.0303
# iter    8/40 | w   -8.2926 | loss  6163.1692 | grad -1307.3649
# iter    9/40 | w   -6.9852 | loss  4572.5641 | grad -1125.9346
# iter   10/40 | w   -5.8593 | loss  3392.8001 | grad -969.6825
# iter   11/40 | w   -4.8896 | loss  2517.7602 | grad -835.1143
# iter   12/40 | w   -4.0545 | loss  1868.7364 | grad -719.2209
# iter   13/40 | w   -3.3353 | loss  1387.3506 | grad -619.4106
# iter   14/40 | w   -2.7159 | loss  1030.3030 | grad -533.4516
# iter   15/40 | w   -2.1824 | loss  765.4781 | grad -459.4216
# iter   16/40 | w   -1.7230 | loss  569.0554 | grad -395.6651
# iter   17/40 | w   -1.3273 | loss  423.3672 | grad -340.7565
# iter   18/40 | w   -0.9866 | loss  315.3092 | grad -293.4678
# iter   19/40 | w   -0.6931 | loss  235.1617 | grad -252.7417
# iter   20/40 | w   -0.4404 | loss  175.7158 | grad -217.6673
# iter   21/40 | w   -0.2227 | loss  131.6242 | grad -187.4604
# iter   22/40 | w   -0.0352 | loss  98.9212 | grad -161.4455
# iter   23/40 | w    0.1262 | loss  74.6651 | grad -139.0408
# iter   24/40 | w    0.2653 | loss  56.6742 | grad -119.7454
# iter   25/40 | w    0.3850 | loss  43.3302 | grad -103.1276
# iter   26/40 | w    0.4881 | loss  33.4328 | grad -88.8161
# iter   27/40 | w    0.5769 | loss  26.0919 | grad -76.4906
# iter   28/40 | w    0.6534 | loss  20.6470 | grad -65.8755
# iter   29/40 | w    0.7193 | loss  16.6086 | grad -56.7336
# iter   30/40 | w    0.7760 | loss  13.6132 | grad -48.8604
# iter   31/40 | w    0.8249 | loss  11.3915 | grad -42.0798
# iter   32/40 | w    0.8670 | loss   9.7437 | grad -36.2401
# iter   33/40 | w    0.9032 | loss   8.5215 | grad -31.2109
# iter   34/40 | w    0.9344 | loss   7.6149 | grad -26.8796
# iter   35/40 | w    0.9613 | loss   6.9425 | grad -23.1494
# iter   36/40 | w    0.9845 | loss   6.4438 | grad -19.9368
# iter   37/40 | w    1.0044 | loss   6.0739 | grad -17.1701
# iter   38/40 | w    1.0216 | loss   5.7996 | grad -14.7873
# iter   39/40 | w    1.0364 | loss   5.5961 | grad -12.7352

# %% [markdown]
# ### Exercise 5c: Make a trace plot
#
# Make a trace plot showing convergence from multiple different starting values for $w$. What do you notice?

# %%
wopt4, info_dict4 = minimize_via_grad_descent(calc_loss, calc_grad, init_w=5, step_size=0.001, max_iters = 40)
wopt5, info_dict5 = minimize_via_grad_descent(calc_loss, calc_grad, init_w = 2, step_size = 0.001, max_iters = 40)
wopt6, info_dict6 = minimize_via_grad_descent(calc_loss, calc_grad, init_w = 1, step_size = 0.001, max_iters = 40)
# Out:
# iter    0/40 | w    5.0000 | loss  1045.2307 | grad  537.3210
# iter    1/40 | w    4.4627 | loss  776.5501 | grad  462.7540
# iter    2/40 | w    3.9999 | loss  577.2676 | grad  398.5351
# iter    3/40 | w    3.6014 | loss  429.4583 | grad  343.2282
# iter    4/40 | w    3.2582 | loss  319.8270 | grad  295.5965
# iter    5/40 | w    2.9626 | loss  238.5126 | grad  254.5749
# iter    6/40 | w    2.7080 | loss  178.2011 | grad  219.2462
# iter    7/40 | w    2.4887 | loss  133.4676 | grad  188.8202
# iter    8/40 | w    2.2999 | loss  100.2885 | grad  162.6166
# iter    9/40 | w    2.1373 | loss  75.6792 | grad  140.0494
# iter   10/40 | w    1.9973 | loss  57.4263 | grad  120.6139
# iter   11/40 | w    1.8766 | loss  43.8881 | grad  103.8757
# iter   12/40 | w    1.7728 | loss  33.8466 | grad  89.4603
# iter   13/40 | w    1.6833 | loss  26.3988 | grad  77.0454
# iter   14/40 | w    1.6063 | loss  20.8747 | grad  66.3534
# iter   15/40 | w    1.5399 | loss  16.7774 | grad  57.1451
# iter   16/40 | w    1.4828 | loss  13.7384 | grad  49.2148
# iter   17/40 | w    1.4335 | loss  11.4844 | grad  42.3850
# iter   18/40 | w    1.3912 | loss   9.8126 | grad  36.5030
# iter   19/40 | w    1.3547 | loss   8.5726 | grad  31.4373
# iter   20/40 | w    1.3232 | loss   7.6528 | grad  27.0745
# iter   21/40 | w    1.2961 | loss   6.9707 | grad  23.3173
# iter   22/40 | w    1.2728 | loss   6.4647 | grad  20.0814
# iter   23/40 | w    1.2528 | loss   6.0894 | grad  17.2946
# iter   24/40 | w    1.2355 | loss   5.8111 | grad  14.8945
# iter   25/40 | w    1.2206 | loss   5.6046 | grad  12.8275
# iter   26/40 | w    1.2077 | loss   5.4515 | grad  11.0474
# iter   27/40 | w    1.1967 | loss   5.3379 | grad   9.5143
# iter   28/40 | w    1.1872 | loss   5.2537 | grad   8.1939
# iter   29/40 | w    1.1790 | loss   5.1912 | grad   7.0568
# iter   30/40 | w    1.1719 | loss   5.1448 | grad   6.0775
# iter   31/40 | w    1.1658 | loss   5.1105 | grad   5.2341
# iter   32/40 | w    1.1606 | loss   5.0850 | grad   4.5077
# iter   33/40 | w    1.1561 | loss   5.0661 | grad   3.8822
# iter   34/40 | w    1.1522 | loss   5.0520 | grad   3.3434
# iter   35/40 | w    1.1489 | loss   5.0416 | grad   2.8794
# iter   36/40 | w    1.1460 | loss   5.0339 | grad   2.4798
# iter   37/40 | w    1.1435 | loss   5.0282 | grad   2.1357
# iter   38/40 | w    1.1414 | loss   5.0239 | grad   1.8393
# iter   39/40 | w    1.1395 | loss   5.0208 | grad   1.5841
# iter    0/40 | w    2.0000 | loss  57.7576 | grad  120.9944
# iter    1/40 | w    1.8790 | loss  44.1337 | grad  104.2034
# iter    2/40 | w    1.7748 | loss  34.0288 | grad  89.7425
# iter    3/40 | w    1.6851 | loss  26.5339 | grad  77.2884
# iter    4/40 | w    1.6078 | loss  20.9749 | grad  66.5627
# iter    5/40 | w    1.5412 | loss  16.8518 | grad  57.3254
# iter    6/40 | w    1.4839 | loss  13.7936 | grad  49.3701
# iter    7/40 | w    1.4345 | loss  11.5253 | grad  42.5187
# iter    8/40 | w    1.3920 | loss   9.8429 | grad  36.6181
# iter    9/40 | w    1.3554 | loss   8.5951 | grad  31.5364
# iter   10/40 | w    1.3238 | loss   7.6695 | grad  27.1600
# iter   11/40 | w    1.2967 | loss   6.9830 | grad  23.3908
# iter   12/40 | w    1.2733 | loss   6.4739 | grad  20.1447
# iter   13/40 | w    1.2531 | loss   6.0962 | grad  17.3492
# iter   14/40 | w    1.2358 | loss   5.8161 | grad  14.9415
# iter   15/40 | w    1.2209 | loss   5.6084 | grad  12.8680
# iter   16/40 | w    1.2080 | loss   5.4543 | grad  11.0822
# iter   17/40 | w    1.1969 | loss   5.3400 | grad   9.5443
# iter   18/40 | w    1.1874 | loss   5.2552 | grad   8.2198
# iter   19/40 | w    1.1791 | loss   5.1923 | grad   7.0791
# iter   20/40 | w    1.1721 | loss   5.1457 | grad   6.0967
# iter   21/40 | w    1.1660 | loss   5.1111 | grad   5.2506
# iter   22/40 | w    1.1607 | loss   5.0854 | grad   4.5219
# iter   23/40 | w    1.1562 | loss   5.0664 | grad   3.8944
# iter   24/40 | w    1.1523 | loss   5.0523 | grad   3.3540
# iter   25/40 | w    1.1489 | loss   5.0418 | grad   2.8885
# iter   26/40 | w    1.1461 | loss   5.0341 | grad   2.4877
# iter   27/40 | w    1.1436 | loss   5.0283 | grad   2.1424
# iter   28/40 | w    1.1414 | loss   5.0240 | grad   1.8451
# iter   29/40 | w    1.1396 | loss   5.0209 | grad   1.5891
# iter   30/40 | w    1.1380 | loss   5.0185 | grad   1.3685
# iter   31/40 | w    1.1366 | loss   5.0168 | grad   1.1786
# iter   32/40 | w    1.1354 | loss   5.0155 | grad   1.0151
# iter   33/40 | w    1.1344 | loss   5.0145 | grad   0.8742
# iter   34/40 | w    1.1336 | loss   5.0138 | grad   0.7529
# iter   35/40 | w    1.1328 | loss   5.0133 | grad   0.6484
# iter   36/40 | w    1.1322 | loss   5.0129 | grad   0.5584
# iter   37/40 | w    1.1316 | loss   5.0126 | grad   0.4809
# iter   38/40 | w    1.1311 | loss   5.0124 | grad   0.4142
# iter   39/40 | w    1.1307 | loss   5.0122 | grad   0.3567
# iter    0/40 | w    1.0000 | loss   6.1509 | grad -17.7811
# iter    1/40 | w    1.0178 | loss   5.8567 | grad -15.3135
# iter    2/40 | w    1.0331 | loss   5.6384 | grad -13.1884
# iter    3/40 | w    1.0463 | loss   5.4766 | grad -11.3581
# iter    4/40 | w    1.0576 | loss   5.3565 | grad  -9.7819
# iter    5/40 | w    1.0674 | loss   5.2675 | grad  -8.4244
# iter    6/40 | w    1.0758 | loss   5.2014 | grad  -7.2553
# iter    7/40 | w    1.0831 | loss   5.1524 | grad  -6.2485
# iter    8/40 | w    1.0894 | loss   5.1161 | grad  -5.3813
# iter    9/40 | w    1.0947 | loss   5.0891 | grad  -4.6345
# iter   10/40 | w    1.0994 | loss   5.0692 | grad  -3.9914
# iter   11/40 | w    1.1034 | loss   5.0543 | grad  -3.4375
# iter   12/40 | w    1.1068 | loss   5.0433 | grad  -2.9604
# iter   13/40 | w    1.1098 | loss   5.0352 | grad  -2.5496
# iter   14/40 | w    1.1123 | loss   5.0291 | grad  -2.1958
# iter   15/40 | w    1.1145 | loss   5.0246 | grad  -1.8911
# iter   16/40 | w    1.1164 | loss   5.0213 | grad  -1.6286
# iter   17/40 | w    1.1180 | loss   5.0188 | grad  -1.4026
# iter   18/40 | w    1.1194 | loss   5.0170 | grad  -1.2080
# iter   19/40 | w    1.1206 | loss   5.0157 | grad  -1.0403
# iter   20/40 | w    1.1217 | loss   5.0147 | grad  -0.8960
# iter   21/40 | w    1.1226 | loss   5.0139 | grad  -0.7716
# iter   22/40 | w    1.1233 | loss   5.0134 | grad  -0.6645
# iter   23/40 | w    1.1240 | loss   5.0129 | grad  -0.5723
# iter   24/40 | w    1.1246 | loss   5.0126 | grad  -0.4929
# iter   25/40 | w    1.1251 | loss   5.0124 | grad  -0.4245
# iter   26/40 | w    1.1255 | loss   5.0122 | grad  -0.3656
# iter   27/40 | w    1.1259 | loss   5.0121 | grad  -0.3148
# iter   28/40 | w    1.1262 | loss   5.0120 | grad  -0.2712
# iter   29/40 | w    1.1264 | loss   5.0120 | grad  -0.2335
# iter   30/40 | w    1.1267 | loss   5.0119 | grad  -0.2011
# iter   31/40 | w    1.1269 | loss   5.0119 | grad  -0.1732
# iter   32/40 | w    1.1271 | loss   5.0118 | grad  -0.1492
# iter   33/40 | w    1.1272 | loss   5.0118 | grad  -0.1285
# iter   34/40 | w    1.1273 | loss   5.0118 | grad  -0.1106
# iter   35/40 | w    1.1274 | loss   5.0118 | grad  -0.0953
# iter   36/40 | w    1.1275 | loss   5.0118 | grad  -0.0821
# iter   37/40 | w    1.1276 | loss   5.0118 | grad  -0.0707
# iter   38/40 | w    1.1277 | loss   5.0118 | grad  -0.0609
# iter   39/40 | w    1.1278 | loss   5.0118 | grad  -0.0524

# %%
fig, axes = plt.subplots(nrows=1, ncols=5, sharex=True, sharey=False, figsize=(16,5))
axes[0].plot(info_dict2['trace_loss_list'], '.-');
axes[0].set_title('loss with initial w=10');
axes[1].plot(info_dict3['trace_loss_list'], '.-');
axes[1].set_title('loss with initial w=-30');
axes[2].plot(info_dict4['trace_loss_list'], '.-');
axes[2].set_title('loss with initial w=5');
axes[3].plot(info_dict5['trace_loss_list'], '.-');
axes[3].set_title('loss with initial w=2');
axes[4].plot(info_dict6['trace_loss_list'], '.-');
axes[4].set_title('loss with initial w=1');

fig.tight_layout()

# %% [markdown]
# <a id="part6"></a>
#
#
# # Part 6: Using scipy's built-in gradient optimization tools

# %%
import scipy.optimize

# %% [markdown]
# Take a look at SciPy's built in minimization toolbox
#
# <https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize>
#
# We'll use "L-BFGS", a "quasi-newton" method, which you can get an intuition for here:
#
# https://en.wikipedia.org/wiki/Newton%27s_method_in_optimization

# %%
result = scipy.optimize.minimize(calc_loss, 0.0, jac=calc_grad, method='L-BFGS-B')

# Returns an object with several fields, let's print the result to get an idea
print(result)
# Out:
#   message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#   success: True
#    status: 0
#       fun: 5.011759943825979
#         x: [ 1.128e+00]
#       nit: 2
#       jac: [-2.842e-14]
#      nfev: 3
#      njev: 3
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>

# %%
print(str(result.message))
# Out:
# CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL

# %%
best_w = result.x
print(best_w)
# Out:
# [1.12812831]
